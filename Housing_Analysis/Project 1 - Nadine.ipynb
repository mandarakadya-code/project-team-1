# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

Demographic = "Resources/Demographic.csv"
House_Prices= "Resources/House_Prices.csv"
interest_Rates="Resources/interest_Rates.csv"


Raw_data_info = {"Age Group": ["25 to 29 years","30 to 34 years","35 to 39 years","40 to 44 years","45 to 49 years","50 to 54 years","55 to 59 years","60 to 64 years","65 to 69 years","70 to 74 years","75 to 84 years","85 years and older"],
    "Year": [2011,2016,2021]
    }
info_df = pd.DataFrame(raw_data_info, columns= ["Ref_DATE", "GEO", "DGUID", "New housing", "Price indexes", "UO,_ID", "SCALAR_ID","VECTOR", "COOORDINATE","VALUE","STATUS","SYMBOL","TERMINATED","DECIMALS"])
info_df
# Out:
# Empty DataFrame
# Columns: [Ref_DATE, GEO, DGUID, New housing, Price indexes, UO,_ID, SCALAR_ID, VECTOR, COOORDINATE, VALUE, STATUS, SYMBOL, TERMINATED, DECIMALS]
# Index: []

# %%
Demo_df=pd.read_csv(Demographic)
Demo_df.head()
# Out:
#         Age Group  2011  2016  2021
# 0  25 to 29 years  44.1  39.6  36.5
# 1  30 to 34 years  59.2  55.0  52.3
# 2  35 to 39 years  67.1  63.5  61.5
# 3  40 to 44 years  71.0  69.0  66.8
# 4  45 to 49 years  73.8  71.8  70.6

# %%
House_Prices_df=pd.read_csv(House_Prices, skiprows=1)
House_Prices_df.head()
# Out:
#      REF_DATE              GEO           DGUID New housing price indexes  \
# 0  2019-01-01           Canada  2016A000011124    Total (house and land)
# 1  2019-01-01           Canada  2016A000011124                House only
# 2  2019-01-01           Canada  2016A000011124                 Land only
# 3  2019-01-01  Atlantic Region      2016A00011    Total (house and land)
# 4  2019-01-01  Atlantic Region      2016A00011                House only
#
#                  UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID      VECTOR  COORDINATE  \
# 0  Index, 201612=100     347         units          0  v111955442         1.1
# 1  Index, 201612=100     347         units          0  v111955443         1.2
# 2  Index, 201612=100     347         units          0  v111955444         1.3
# 3  Index, 201612=100     347         units          0  v111955445         2.1
# 4  Index, 201612=100     347         units          0  v111955446         2.2
#
#    VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# ...

# %%
interest_Rates_df=pd.read_csv(interest_Rates)
interest_Rates_df
# Out:
#       REF_DATE     GEO           DGUID      UOM  UOM_ID SCALAR_FACTOR  \
# 0   2019-01-01  Canada  2016A000011124  Percent     239         units
# 1   2019-02-01  Canada  2016A000011124  Percent     239         units
# 2   2019-03-01  Canada  2016A000011124  Percent     239         units
# 3   2019-04-01  Canada  2016A000011124  Percent     239         units
# 4   2019-05-01  Canada  2016A000011124  Percent     239         units
# 5   2019-06-01  Canada  2016A000011124  Percent     239         units
# 6   2019-07-01  Canada  2016A000011124  Percent     239         units
# 7   2019-08-01  Canada  2016A000011124  Percent     239         units
# 8   2019-09-01  Canada  2016A000011124  Percent     239         units
# 9   2019-10-01  Canada  2016A000011124  Percent     239         units
# 10  2019-11-01  Canada  2016A000011124  Percent     239         units
# 11  2019-12-01  Canada  2016A000011124  Percent     239         units
# ...

# %%
print(House_Prices_df.dtypes)
# Out:
# REF_DATE                     datetime64[ns]
# GEO                                  object
# DGUID                                object
# New housing price indexes            object
# UOM                                  object
# UOM_ID                                int64
# SCALAR_FACTOR                        object
# SCALAR_ID                             int64
# VECTOR                               object
# COORDINATE                          float64
# VALUE                               float64
# STATUS                               object
# SYMBOL                              float64
# TERMINATED                          float64
# DECIMALS                              int64
# dtype: object

# %%
print(len(interest_Rates_df))
# Out:
# 874

# %%
print(len(House_Prices_df))
# Out:
# 6960

# %%
House_Prices_df.head()
# Out:
#      REF_DATE              GEO           DGUID New housing price indexes  \
# 0  2019-01-01           Canada  2016A000011124    Total (house and land)
# 1  2019-01-01           Canada  2016A000011124                House only
# 2  2019-01-01           Canada  2016A000011124                 Land only
# 3  2019-01-01  Atlantic Region      2016A00011    Total (house and land)
# 4  2019-01-01  Atlantic Region      2016A00011                House only
#
#                  UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID      VECTOR  COORDINATE  \
# 0  Index, 201612=100     347         units          0  v111955442         1.1
# 1  Index, 201612=100     347         units          0  v111955443         1.2
# 2  Index, 201612=100     347         units          0  v111955444         1.3
# 3  Index, 201612=100     347         units          0  v111955445         2.1
# 4  Index, 201612=100     347         units          0  v111955446         2.2
#
#    VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# ...

# %%
Data2=pd.concat([House_Prices_df,interest_Rates_df],
axis=0,
ignore_index=True)
Data2
# Out:
#                  REF_DATE              GEO           DGUID  \
# 0     2019-01-01 00:00:00           Canada  2016A000011124
# 1     2019-01-01 00:00:00           Canada  2016A000011124
# 2     2019-01-01 00:00:00           Canada  2016A000011124
# 3     2019-01-01 00:00:00  Atlantic Region      2016A00011
# 4     2019-01-01 00:00:00  Atlantic Region      2016A00011
# ...                   ...              ...             ...
# 7013           2023-06-01           Canada  2016A000011124
# 7014           2023-07-01           Canada  2016A000011124
# 7015           2023-08-01           Canada  2016A000011124
# 7016           2023-09-01           Canada  2016A000011124
# 7017           2023-10-01           Canada  2016A000011124
#
#      New housing price indexes                UOM  UOM_ID SCALAR_FACTOR  \
# 0       Total (house and land)  Index, 201612=100     347         units
# 1                   House only  Index, 201612=100     347         units
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st


y={"f(canada)":[2019,2020,2021,2022,2023]}
x=[103,103,109,124,129]

graph=pd.DataFrame(y,x)
graph.plot(kind="line",grid=True, title="House value per year in canada", ylabel="year",xlabel="House value")
# Out:
# <Axes: title={'center': 'House value per year in canada'}, xlabel='House value', ylabel='year'>

# %%
Demo_df.plot(kind="bar",x,y)
# Out:
#   Cell In[198], line 1
#     Demo_df.plot(kind="bar",x,y)
#                                ^
# SyntaxError: positional argument follows keyword argument

# %%
df1=pd.DataFrame(Demo_df)
df1.plot(kind="bar")
plt.ylim(30)
plt.ylabel("percentage of home ownership")
plt.xlabel("Age group")
plt.title("change in home ownership per year")
# Out:
# Text(0.5, 1.0, 'change in home ownership per year')

# %%
Demo_df.set_index("Age Group", inplace=True)

Demo_df1 = Demo_df["2011"]
Demo_df2 = Demo_df["2016"]
Demo_df3 = Demo_df["2021"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/m7/2cs08hqx0qsdqd7wfpm_tlzr0000gn/T/ipykernel_2763/51676445.py in ?()
# ----> 1 Demo_df.set_index("Age Group", inplace=True)
#       2
#       3 Demo_df1 = Demo_df["2011"]
#       4 Demo_df2 = Demo_df["2016"]
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['Age Group'] are in the columns"

# %%
Demo_df1 = pd.DataFrame(Demo_df)
Demo_df1.plot(kind="bar")
plt.ylim(30)
plt.ylabel("percentage of home ownership")
plt.xlabel("Age group")
plt.title("change in home ownership per year")
# Out:
# Text(0.5, 1.0, 'change in home ownership per year')
